# %%
#En este jupyter encontrarás la información clusterizada así como un análisis exploratorio de los datos

# %%
import pandas as pd

from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
# El mantra
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
perretillos = pd.read_csv("perretesint.csv")

# %%
perretillos.columns
# Out:
# Index(['Name', 'Adapts Well To Apartment Living', 'Good For Novice Owners',
#        'Sensitivity Level', 'Tolerates Being Alone', 'Tolerates Cold Weather',
#        'Tolerates Hot Weather', 'Affectionate With Family', 'Kid-Friendly',
#        'Dog Friendly', 'Friendly Toward Strangers', 'Amount Of Shedding',
#        'Drooling Potential', 'Easy To Groom', 'General Health',
#        'Potential For Weight Gain', 'Size', 'Easy To Train', 'Intelligence',
#        'Potential For Mouthiness', 'Prey Drive', 'Tendency To Bark Or Howl',
#        'Wanderlust Potential', 'Energy Level', 'Intensity', 'Exercise Needs',
#        'Potential For Playfulness'],
#       dtype='object')

# %%
perretillos
# Out:
#                             Name  Adapts Well To Apartment Living  \
# 0                         Afador                                1
# 1                    Affenhuahua                                4
# 2                  Affenpinscher                                5
# 3                   Afghan Hound                                5
# 4                         Akbash                                1
# ..                           ...                              ...
# 376  Wirehaired Pointing Griffon                                1
# 377               Xoloitzcuintli                                5
# 378               Yakutian Laika                                1
# 379                     Yorkipoo                                5
# 380            Yorkshire Terrier                                5
#
#      Good For Novice Owners  Sensitivity Level  Tolerates Being Alone  \
# 0                         1                  3                      3
# 1                         4                  4                      1
# 2                         4                  3                      1
# 3                         3                  5                      2
# 4                         2                  3                      4
# ..                      ...                ...                    ...
# 376                       3                  4                      1
# 377                       1                  5                      1
# 378                       3                  3                      1
# 379                       5                  4                      3
# 380                       4                  5                      2
#
#      Tolerates Cold Weather  Tolerates Hot Weather  Affectionate With Family  \
# 0                         4                      2                         4
# 1                         2                      3                         4
# 2                         3                      3                         5
# 3                         5                      5                         5
# 4                         4                      2                         5
# ..                      ...                    ...                       ...
# 376                       4                      3                         5
# 377                       3                      3                         5
# 378                       5                      3                         5
# 379                       2                      3                         5
# 380                       2                      2                         4
#
#      Kid-Friendly  Dog Friendly  ...  Easy To Train  Intelligence  \
# 0               2             3  ...              1             5
# 1               3             2  ...              3             3
# 2               1             4  ...              2             4
# 3               5             4  ...              1             4
# 4               4             3  ...              3             4
# ..            ...           ...  ...            ...           ...
# 376             5             4  ...              5             5
# 377             3             2  ...              3             5
# 378             4             4  ...              4             4
# 379             4             3  ...              4             4
# 380             2             3  ...              3             3
#
#      Potential For Mouthiness  Prey Drive  Tendency To Bark Or Howl  \
# 0                           4           4                         4
# 1                           4           2                         4
# 2                           4           3                         2
# 3                           3           5                         2
# 4                           3           1                         3
# ..                        ...         ...                       ...
# 376                         3           4                         4
# 377                         3           5                         5
# 378                         2           3                         4
# 379                         3           3                         5
# 380                         2           2                         3
#
#      Wanderlust Potential  Energy Level  Intensity  Exercise Needs  \
# 0                       4             4          4               4
# 1                       2             4          3               3
# 2                       2             4          3               3
# 3                       5             5          2               4
# 4                       1             2          2               2
# ..                    ...           ...        ...             ...
# 376                     4             5          3               4
# 377                     5             3          3               3
# 378                     3             4          3               5
# 379                     2             5          3               3
# 380                     3             5          4               4
#
#      Potential For Playfulness
# 0                            3
# 1                            3
# 2                            4
# 3                            4
# 4                            3
# ..                         ...
# 376                          5
# 377                          3
# 378                          4
# 379                          4
# 380                          5
#
# [381 rows x 27 columns]

# %%
perretillos.corr().T
# Out:
#                                  Adapts Well To Apartment Living  \
# Adapts Well To Apartment Living                         1.000000
# Good For Novice Owners                                  0.559226
# Sensitivity Level                                       0.137098
# Tolerates Being Alone                                  -0.022522
# Tolerates Cold Weather                                 -0.346137
# Tolerates Hot Weather                                  -0.083920
# Affectionate With Family                                0.064328
# Kid-Friendly                                           -0.030960
# Dog Friendly                                            0.029867
# Friendly Toward Strangers                               0.106204
# Amount Of Shedding                                     -0.281061
# Drooling Potential                                     -0.307607
# Easy To Groom                                          -0.087240
# General Health                                         -0.006667
# Potential For Weight Gain                               0.036225
# Size                                                   -0.645731
# Easy To Train                                          -0.044185
# Intelligence                                           -0.205670
# Potential For Mouthiness                               -0.070943
# Prey Drive                                             -0.078551
# Tendency To Bark Or Howl                                0.057754
# Wanderlust Potential                                   -0.265455
# Energy Level                                           -0.307029
# Intensity                                              -0.306020
# Exercise Needs                                         -0.475336
# Potential For Playfulness                               0.037886
#
#                                  Good For Novice Owners  Sensitivity Level  \
# Adapts Well To Apartment Living                0.559226           0.137098
# Good For Novice Owners                         1.000000           0.102517
# Sensitivity Level                              0.102517           1.000000
# Tolerates Being Alone                         -0.049049          -0.346562
# Tolerates Cold Weather                        -0.224935          -0.093087
# Tolerates Hot Weather                         -0.002491           0.046082
# Affectionate With Family                       0.181350           0.328923
# Kid-Friendly                                   0.144699           0.218933
# Dog Friendly                                   0.323016           0.190178
# Friendly Toward Strangers                      0.282045           0.186470
# Amount Of Shedding                            -0.211080           0.044614
# Drooling Potential                            -0.340274          -0.040807
# Easy To Groom                                 -0.118613           0.028543
# General Health                                -0.064543          -0.084982
# Potential For Weight Gain                      0.073422          -0.009109
# Size                                          -0.502010          -0.041823
# Easy To Train                                  0.247225           0.250614
# Intelligence                                  -0.031866           0.102594
# Potential For Mouthiness                      -0.139458           0.103981
# Prey Drive                                    -0.130301          -0.005115
# Tendency To Bark Or Howl                       0.013453           0.139015
# Wanderlust Potential                          -0.166286           0.101938
# Energy Level                                  -0.153577           0.083197
# Intensity                                     -0.347275          -0.011190
# Exercise Needs                                -0.319578           0.041473
# Potential For Playfulness                      0.190481           0.302035
#
#                                  Tolerates Being Alone  \
# Adapts Well To Apartment Living              -0.022522
# Good For Novice Owners                       -0.049049
# Sensitivity Level                            -0.346562
# Tolerates Being Alone                         1.000000
# Tolerates Cold Weather                        0.102466
# Tolerates Hot Weather                        -0.047200
# Affectionate With Family                     -0.225839
# Easy To Train                               -0.032451      0.175008
# Intelligence                                 0.152823      0.342705
# Potential For Mouthiness                     0.147169      0.073956
# Prey Drive                                   0.371745      0.268831
# Tendency To Bark Or Howl                     0.180487      0.120930
# Wanderlust Potential                         1.000000      0.404835
# Energy Level                                 0.404835      1.000000
# Intensity                                    0.317722      0.397981
# Exercise Needs                               0.479519      0.703917
# Potential For Playfulness                    0.304986      0.413663
#
#                                  Intensity  Exercise Needs  \
# Adapts Well To Apartment Living  -0.306020       -0.475336
# Good For Novice Owners           -0.347275       -0.319578
# Sensitivity Level                -0.011190        0.041473
# Tolerates Being Alone             0.036733       -0.025838
# Tolerates Cold Weather            0.054956        0.154938
# Tolerates Hot Weather             0.145435        0.342052
# Affectionate With Family          0.002625        0.124062
# Kid-Friendly                      0.064221        0.198673
# Dog Friendly                     -0.037012        0.149486
# Friendly Toward Strangers         0.012060        0.133826
# Amount Of Shedding                0.099484        0.142832
# Drooling Potential               -0.005097        0.001624
# Easy To Groom                     0.201815        0.122983
# General Health                    0.134566        0.179339
# Potential For Weight Gain         0.050418       -0.077862
# Size                              0.134469        0.287432
# Easy To Train                    -0.023649        0.156111
# Intelligence                      0.138319        0.324069
# Potential For Mouthiness          0.083813        0.080420
# Prey Drive                        0.146560        0.304375
# Tendency To Bark Or Howl          0.175901        0.036485
# Wanderlust Potential              0.317722        0.479519
# Energy Level                      0.397981        0.703917
# Intensity                         1.000000        0.422040
# Exercise Needs                    0.422040        1.000000
# Potential For Playfulness         0.227140        0.295087
#
#                                  Potential For Playfulness
# Adapts Well To Apartment Living                   0.037886
# Good For Novice Owners                            0.190481
# Sensitivity Level                                 0.302035
# Tolerates Being Alone                            -0.275111
# Tolerates Cold Weather                           -0.003890
# Tolerates Hot Weather                             0.121252
# Affectionate With Family                          0.489484
# Kid-Friendly                                      0.397273
# Dog Friendly                                      0.322720
# Friendly Toward Strangers                         0.397215
# Amount Of Shedding                                0.006061
# Drooling Potential                               -0.181335
# Easy To Groom                                     0.022936
# General Health                                    0.005062
# Potential For Weight Gain                         0.080912
# Size                                             -0.129725
# Easy To Train                                     0.282105
# Intelligence                                      0.212026
# Potential For Mouthiness                          0.042536
# Prey Drive                                        0.052881
# Tendency To Bark Or Howl                          0.120428
# Wanderlust Potential                              0.304986
# Energy Level                                      0.413663
# Intensity                                         0.227140
# Exercise Needs                                    0.295087
# Potential For Playfulness                         1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# # Vamos a hacer el Codo

# %%
perretessinnombre = perretillos.drop(['Name','Tolerates Cold Weather','Tolerates Hot Weather', 'Size', 'Drooling Potential', 'Amount Of Shedding', 'Easy To Groom', 'General Health', 'Potential For Weight Gain'], axis=1)

# %%
kmeans = [KMeans(n_clusters=i) for i in range(1,40)]
for model in kmeans:
    model.fit(perretessinnombre)

# %%
inertias = [model.inertia_ for model in kmeans]
inertias[:3]
# Out:
# [7141.039370078741, 6083.02480136835, 5452.508361678004]

# %%
plt.plot(range(1,40),inertias)
plt.xticks(range(1,40));

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
km = KMeans(n_clusters=13)
km.fit(perretessinnombre)
# Out:
# KMeans(n_clusters=13)

# %%
y_pred = km.predict(perretessinnombre)

# %%
perretessinnombre["predict"] = y_pred

# %%
perretessinnombre["predict"].unique()
# Out:
# array([ 4,  6, 12,  5,  3, 10,  8,  2,  9,  1,  7, 11,  0], dtype=int32)

# %%
perretessinpredict= perretessinnombre.drop("predict", axis=1)

# %%
silhouette_score(perretessinpredict, y_pred)
# Out:
# 0.07688169548430102

# %%
#scalar y volver a probar

# %%
dat_ = perretessinpredict.copy()

# %% [markdown]
# # Escalamos datos

# %%
scaler = StandardScaler()
df_scaler = pd.DataFrame(scaler.fit_transform(dat_), columns=dat_.columns)

# %%
kmeans = [KMeans(n_clusters=i) for i in range(1,21)]
for model in kmeans:
    model.fit(dat_)

# %%
inertias = [model.inertia_ for model in kmeans]
inertias[:3]
# Out:
# [7141.039370078741, 6083.02480136835, 5452.580920225509]

# %%
plt.plot(range(1,21),inertias)
plt.xticks(range(1,21));

# %%
kmestandar = KMeans(n_clusters=6)
kmestandar.fit(dat_)
# Out:
# KMeans(n_clusters=6)

# %%
y_yanose = kmestandar.predict(dat_)

# %% [markdown]
# ### Silueta datos estandarizados

# %%
silhouette_score(dat_, y_yanose)
# Out:
# 0.09493487006484465

# %% [markdown]
# # PCA DE 2

# %%
pecea2 = perretessinpredict.copy()

# %%
pca = PCA(2)
pecea_t2 = pd.DataFrame(pca.fit_transform(pecea2), columns=["PC1", "PC2"] )

# %%
km2 = KMeans(n_clusters=6)
km2.fit(pecea_t2)
# Out:
# KMeans(n_clusters=6)

# %%
y_pece = km2.predict(pecea_t2)

# %%
# Silueta datos PCA de 2

# %%
silhouette_score(pecea_t2, y_pece)
# Out:
# 0.36627199234721075

# %%
pecea_t2["grupetes"] = y_pece

# %%
pca_perros2 = sns.scatterplot(pecea_t2["PC1"],pecea_t2["PC2"], hue=pecea_t2["grupetes"]);
# Out:
# /home/mariadelas/anaconda3/envs/ironhack/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pecea_t2["grupetes"].value_counts()
# Out:
# 0    99
# 2    82
# 3    67
# 4    56
# 5    41
# 1    36
# Name: grupetes, dtype: int64

# %%
perretessinnombre["groups"] = y_pece

# %%
a = perretessinnombre.groups == 2

# %%
perretessinnombre.columns
# Out:
# Index(['Adapts Well To Apartment Living', 'Good For Novice Owners',
#        'Sensitivity Level', 'Tolerates Being Alone',
#        'Affectionate With Family', 'Kid-Friendly', 'Dog Friendly',
#        'Friendly Toward Strangers', 'Easy To Train', 'Intelligence',
#        'Potential For Mouthiness', 'Prey Drive', 'Tendency To Bark Or Howl',
#        'Wanderlust Potential', 'Energy Level', 'Intensity', 'Exercise Needs',
#        'Potential For Playfulness', 'predict', 'groups'],
#       dtype='object')

# %%
columnassinnombre = ['Adapts Well To Apartment Living', 'Good For Novice Owners',
       'Sensitivity Level', 'Tolerates Being Alone',
       'Affectionate With Family', 'Kid-Friendly', 'Dog Friendly',
       'Friendly Toward Strangers', 'Easy To Train', 'Intelligence',
       'Potential For Mouthiness', 'Prey Drive', 'Tendency To Bark Or Howl',
       'Wanderlust Potential', 'Energy Level', 'Intensity', 'Exercise Needs',
       'Potential For Playfulness', 'predict', 'groups']

# %%
len(columnassinnombre)
# Out:
# 20

# %%
#Agrupar por columnas

# %%
perretessinnombre.head(1)
# Out:
#    Adapts Well To Apartment Living  Good For Novice Owners  Sensitivity Level  \
# 0                                1                       1                  3
#
#    Tolerates Being Alone  Affectionate With Family  Kid-Friendly  \
# 0                      3                         4             2
#
#    Dog Friendly  Friendly Toward Strangers  Easy To Train  Intelligence  \
# 0             3                          1              1             5
#
#    Potential For Mouthiness  Prey Drive  Tendency To Bark Or Howl  \
# 0                         4           4                         4
#
#    Wanderlust Potential  Energy Level  Intensity  Exercise Needs  \
# 0                     4             4          4               4
#
#    Potential For Playfulness  predict  groups
# 0                          3        4       5

# %%
perretessinnombre["Adaptation"]= round(perretessinnombre[['Adapts Well To Apartment Living', 'Good For Novice Owners','Sensitivity Level', 'Tolerates Being Alone']].mean(axis=1),0)

# %%
perretessinnombre["Afecttion"]= round(perretessinnombre[['Affectionate With Family', 'Kid-Friendly','Dog Friendly', 'Friendly Toward Strangers']].mean(axis=1),0)

# %%
perretessinnombre["Trainability"]= round(perretessinnombre[['Easy To Train', 'Intelligence',
       'Potential For Mouthiness', 'Prey Drive', 'Tendency To Bark Or Howl',
       'Wanderlust Potential']].mean(axis=1),0)

# %%
perretessinnombre["Physical Needs"]= round(perretessinnombre[['Energy Level', 'Intensity', 'Exercise Needs',
       'Potential For Playfulness']].mean(axis=1),0)

# %%
perretessinnombre
# Out:
#      Adapts Well To Apartment Living  Good For Novice Owners  \
# 0                                  1                       1
# 1                                  4                       4
# 2                                  5                       4
# 3                                  5                       3
# 4                                  1                       2
# ..                               ...                     ...
# 376                                1                       3
# 377                                5                       1
# 378                                1                       3
# 379                                5                       5
# 380                                5                       4
#
#      Sensitivity Level  Tolerates Being Alone  Affectionate With Family  \
# 0                    3                      3                         4
# 1                    4                      1                         4
# 2                    3                      1                         5
# 3                    5                      2                         5
# 4                    3                      4                         5
# ..                 ...                    ...                       ...
# 376                  4                      1                         5
# 377                  5                      1                         5
# 378                  3                      1                         5
# 379                  4                      3                         5
# 380                  5                      2                         4
#
#      Kid-Friendly  Dog Friendly  Friendly Toward Strangers  Easy To Train  \
# 0               2             3                          1              1
# 1               3             2                          2              3
# 2               1             4                          3              2
# 3               5             4                          2              1
# 4               4             3                          2              3
# ..            ...           ...                        ...            ...
# 376             5             4                          5              5
# 377             3             2                          1              3
# 378             4             4                          4              4
# 379             4             3                          2              4
# 380             2             3                          2              3
#
#      Intelligence  ...  Energy Level  Intensity  Exercise Needs  \
# 0               5  ...             4          4               4
# 1               3  ...             4          3               3
# 2               4  ...             4          3               3
# 3               4  ...             5          2               4
# 4               4  ...             2          2               2
# ..            ...  ...           ...        ...             ...
# 376             5  ...             5          3               4
# 377             5  ...             3          3               3
# 378             4  ...             4          3               5
# 379             4  ...             5          3               3
# 380             3  ...             5          4               4
#
#      Potential For Playfulness  predict  groups  Adaptation  Afecttion  \
# 0                            3        4       5         2.0        2.0
# 1                            3        6       4         3.0        3.0
# 2                            4        6       4         3.0        3.0
# 3                            4       12       0         4.0        4.0
# 4                            3        5       1         2.0        4.0
# ..                         ...      ...     ...         ...        ...
# 376                          5        7       2         2.0        5.0
# 377                          3       12       0         3.0        3.0
# 378                          4        9       0         2.0        4.0
# 379                          4        6       4         4.0        4.0
# 380                          5        6       4         4.0        3.0
#
#      Trainability  Physical Needs
# 0             4.0             4.0
# 1             3.0             3.0
# 2             3.0             4.0
# 3             3.0             4.0
# 4             2.0             2.0
# ..            ...             ...
# 376           4.0             4.0
# 377           4.0             3.0
# 378           3.0             4.0
# 379           4.0             4.0
# 380           3.0             4.0
#
# [381 rows x 24 columns]

# %%
perretillos = perretessinnombre

# %%
perretillos.columns
# Out:
# Index(['Adapts Well To Apartment Living', 'Good For Novice Owners',
#        'Sensitivity Level', 'Tolerates Being Alone',
#        'Affectionate With Family', 'Kid-Friendly', 'Dog Friendly',
#        'Friendly Toward Strangers', 'Easy To Train', 'Intelligence',
#        'Potential For Mouthiness', 'Prey Drive', 'Tendency To Bark Or Howl',
#        'Wanderlust Potential', 'Energy Level', 'Intensity', 'Exercise Needs',
#        'Potential For Playfulness', 'predict', 'groups', 'Adaptation',
#        'Afecttion', 'Trainability', 'Physical Needs'],
#       dtype='object')

# %%
#mirar en los clusters caract fisicas como frio calor y size  Drooling Potential***** Amount Of Shedding**Easy To Groom**General Health,  Potential For Weight Gain

# %%
#Gráficps

# %%
sns.countplot(x=perretillos.groups);

# %%
sns.countplot(x="groups", hue="Afecttion", data = perretillos);

# %%
# Los grupos más amorosos son  el 0 el 3 y el 5. El más despegado es el 2

# %%
#La variable de salud tiene puntuaciones poco dispersas. El grupo, es el más resistente es el 1

# %%
sns.countplot(x="groups", hue="Trainability", data = perretillos);

# %%
#El grupo 0 es el más entrenable

# %%
sns.countplot(x="groups", hue="Physical Needs", data = perretillos);

# %%
#El grupo 0 tiene claramente más necesidades físicas

# %%
#Resumen:
    # Los grupos más amorosos son  el 0 el 3 y el 5. El más despegado es el 2
    #La variable de salud tiene puntuaciones poco dispersas. El grupo, es el más resistente es el 1
    #El grupo 0 es el más entrenable
    #El grupo 0 tiene claramente más necesidades físicas

# %% [markdown]
# # vamos a analizar más los grupetes

# %%
perretillos.groupby(['groups'])["Adapts Well To Apartment Living"].mean()
# Out:
# groups
# 0    2.919192
# 1    2.666667
# 2    1.865854
# 3    4.343284
# 4    4.571429
# 5    1.292683
# Name: Adapts Well To Apartment Living, dtype: float64

# %%
perretillos_0 = perretillos.loc[(perretillos.groups == 0)]
perretillos_1 = perretillos.loc[(perretillos.groups == 1)]
perretillos_2 = perretillos.loc[(perretillos.groups == 2)]
perretillos_3 = perretillos.loc[(perretillos.groups == 3)]
perretillos_4 = perretillos.loc[(perretillos.groups == 4)]
perretillos_5 = perretillos.loc[(perretillos.groups == 5)]

# %%
resumen = perretillos.columns[28:]

# %%
resumen
# Out:
# Index([], dtype='object')

# %%
perretillos_0_analisis = [ round(perretillos_0[columnassinnombre[0]].mean(),1), round(perretillos_0[columnassinnombre[1]].mean(),1), round(perretillos_0[columnassinnombre[2]].mean(),1), round(perretillos_0[columnassinnombre[3]].mean(),1), round(perretillos_0[columnassinnombre[4]].mean(),1)]

# %%
perretillos_1_analisis = [ round(perretillos_1[columnassinnombre[0]].mean(),1), round(perretillos_1[columnassinnombre[1]].mean(),1), round(perretillos_1[columnassinnombre[2]].mean(),1), round(perretillos_1[columnassinnombre[3]].mean(),1), round(perretillos_1[columnassinnombre[4]].mean(),1)]

# %%
perretillos_2_analisis = [ round(perretillos_2[columnassinnombre[0]].mean(),1), round(perretillos_2[columnassinnombre[1]].mean(),1), round(perretillos_2[columnassinnombre[2]].mean(),1), round(perretillos_2[columnassinnombre[3]].mean(),1), round(perretillos_2[columnassinnombre[4]].mean(),1)]

# %%
perretillos_3_analisis = [ round(perretillos_3[columnassinnombre[0]].mean(),1), round(perretillos_3[columnassinnombre[1]].mean(),1), round(perretillos_3[columnassinnombre[2]].mean(),1), round(perretillos_3[columnassinnombre[3]].mean(),1), round(perretillos_3[columnassinnombre[4]].mean(),1)]

# %%
perretillos_4_analisis = [ round(perretillos_4[columnassinnombre[0]].mean(),1), round(perretillos_4[columnassinnombre[1]].mean(),1), round(perretillos_4[columnassinnombre[2]].mean(),1), round(perretillos_4[columnassinnombre[3]].mean(),1), round(perretillos_4[columnassinnombre[4]].mean(),1)]

# %%
perretillos_5_analisis = [ round(perretillos_5[columnassinnombre[0]].mean(),1), round(perretillos_5[columnassinnombre[1]].mean(),1), round(perretillos_5[columnassinnombre[2]].mean(),1), round(perretillos_5[columnassinnombre[3]].mean(),1), round(perretillos_5[columnassinnombre[4]].mean(),1)]

# %%
perretillos_0_analisis
# Out:
# [2.9, 2.6, 3.5, 2.2, 4.5]

# %%
resumen_grupos = pd.DataFrame(perretillos_0_analisis, resumen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-8401c85eb1da> in <module>
# ----> 1 resumen_grupos = pd.DataFrame(perretillos_0_analisis, resumen)
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (5, 1), indices imply (0, 1)

# %%
resumen_grupos["1"]= (perretillos_1_analisis)

# %% [markdown]
# ##### resumen_grupos["2"]= (perretillos_2_analisis)
# resumen_grupos["3"]= (perretillos_3_analisis)
# resumen_grupos["4"]= (perretillos_4_analisis)
# resumen_grupos["5"]= (perretillos_5_analisis)

# %%
resumen_grupos
# Out:
#                     0    1    2    3    4    5
# Adaptation        2.9  2.7  1.9  4.3  4.6  1.3
# Afecttion         2.6  1.8  2.4  4.0  3.9  1.5
# Health & Gruming  3.5  3.2  4.0  4.1  3.7  3.4
# Trainability      2.2  2.7  1.9  1.8  2.0  2.1
# Physical Needs    3.3  3.8  4.9  4.9  4.6  4.3

# %%
lista_0 = []
for x in perretillos_0_analisis:
    if x<3:
        lista_0.append("bajo")
    elif x >= 3 and x < 4:
        lista_0.append("medio")
    else:
        lista_0.append("alto")

# %%
lista_1 = []
for x in perretillos_1_analisis:
    if x<3:
        lista_1.append("bajo")
    elif x >= 3 and x < 4:
        lista_1.append("medio")
    else:
        lista_1.append("alto")

# %%
lista_2 = []
for x in perretillos_2_analisis:
    if x<3:
        lista_2.append("bajo")
    elif x >= 3 and x < 4:
        lista_2.append("medio")
    else:
        lista_2.append("alto")

# %%
lista_3 = []
for x in perretillos_3_analisis:
    if x<3:
        lista_3.append("bajo")
    elif x >= 3 and x < 4:
        lista_3.append("medio")
    else:
        lista_3.append("alto")

# %%
lista_4 = []
for x in perretillos_4_analisis:
    if x<3:
        lista_4.append("bajo")
    elif x >= 3 and x < 4:
        lista_4.append("medio")
    else:
        lista_4.append("alto")

# %%
lista_5 = []
for x in perretillos_5_analisis:
    if x<3:
        lista_5.append("bajo")
    elif x >= 3 and x < 4:
        lista_5.append("medio")
    else:
        lista_5.append("alto")

# %%
resumen_cualit = pd.DataFrame(lista_0, resumen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-215-0f862e29883d> in <module>
# ----> 1 resumen_cualit = pd.DataFrame(lista_0, resumen)
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     709                     )
#     710                 else:
# --> 711                     mgr = ndarray_to_mgr(
#     712                         data,
#     713                         index,
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (5, 1), indices imply (0, 1)

# %%
resumen_cualit
# Out:
#                       0      1      2      3      4      5
# Adaptation         bajo   alto   bajo   bajo   bajo   alto
# Afecttion          bajo  medio   bajo   bajo   bajo   alto
# Health & Gruming  medio  medio  medio  medio  medio   alto
# Trainability       bajo   bajo   bajo   bajo   bajo   bajo
# Physical Needs    medio   bajo  medio  medio  medio  medio

# %%
resumen_cualit["1"]= (lista_1)
resumen_cualit["2"]= (lista_2)
resumen_cualit["3"]= (lista_3)
resumen_cualit["4"]= (lista_4)
resumen_cualit["5"]= (lista_5)

# %%
resumen_cualit
# Out:
#                       0      1     2     3      4      5
# Adaptation         bajo   bajo  bajo  alto   alto   bajo
# Afecttion          bajo   bajo  bajo  alto  medio   bajo
# Health & Gruming  medio  medio  alto  alto  medio  medio
# Trainability       bajo   bajo  bajo  bajo   bajo   bajo
# Physical Needs    medio  medio  alto  alto   alto   alto
