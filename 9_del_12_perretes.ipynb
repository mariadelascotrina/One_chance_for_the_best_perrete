# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver)
driver.get("https://dogtime.com/dog-breeds")


driver.implicitly_wait(1) 
driver.find_element_by_css_selector("body > div.ConsentManager__Overlay-np32r2-0.gDTHbw > div.Card-sc-1s2p2gv-0.Layer-sc-3vtlsk-0.ftFbdb.krUWJz > div.Frame-sc-1d4hofp-0.hmNhIY > button").click()  
driver.implicitly_wait(1) 
driver.find_element_by_css_selector("body > div.ConsentManager__Overlay-np32r2-0.gDTHbw > div.Card-sc-1s2p2gv-0.Layer-sc-3vtlsk-0.ftFbdb.krUWJz > div.Card__CardHeader-sc-1s2p2gv-1.Layer__StyledLayerHeader-sc-3vtlsk-1.cemlHZ.ggWNdk > div > button").click()
driver.find_element_by_css_selector("#cookieNotice > div:nth-child(3) > a.cnaccept").click()

lis_dic = []

for l in ("abcdefghijklmnoprstvwxy"):
    for c in range (1,68):
        try:
            driver.get("https://dogtime.com/dog-breeds")
            dic = {}
            dic["Name"] = driver.find_element_by_css_selector(f"body > div.wrapper > div.inner-wrapper > div > div.group.with-image-mobile-only > div.article-crumbs.group-letter.letter-{l}.js-letter-section.paws > div:nth-child({c}) > a").text
            a = driver.find_element_by_css_selector(f" body > div.wrapper > div.inner-wrapper > div > div.group.with-image-mobile-only > div.article-crumbs.group-letter.letter-{l}.js-letter-section.paws > div:nth-child({c}) > a").click()
            dic["Adapts Well To Apartment Living"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(2) > a > div.characteristic-star-block").text
            dic["Good For Novice Owners"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(3) > a > div.characteristic-star-block").text
            dic["Sensitivity Level"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(4) > a > div.characteristic-star-block").text
            dic["Tolerates Being Alone"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(5) > a > div.characteristic-star-block").text
            dic["Tolerates Cold Weather"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(6) > a > div.characteristic-star-block").text
            dic["Tolerates Hot Weather"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(2) > div:nth-child(7) > a > div.characteristic-star-block").text

            dic["Affectionate With Family"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(3) > div:nth-child(2) > a > div.characteristic-star-block").text
            dic["Kid-Friendly"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(3) > div:nth-child(3) > a > div.characteristic-star-block").text
            dic["Dog Friendly"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(3) > div:nth-child(4) > a > div.characteristic-star-block").text
            dic["Friendly Toward Strangers"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(3) > div:nth-child(5) > a > div.characteristic-star-block").text

            
            dic["Amount Of Shedding"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(2) > a > div.characteristic-star-block").text
            dic["Drooling Potential"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(3) > a > div.characteristic-star-block").text
            dic["Easy To Groom"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(4) > a > div.characteristic-star-block").text
            dic["General Health"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(5) > a > div.characteristic-star-block").text
            dic["Potential For Weight Gain"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(6) > a > div.characteristic-star-block").text
            dic["Size"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(4) > div:nth-child(7) > a > div.characteristic-star-block").text

            dic["Easy To Train"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(2) > a > div.characteristic-star-block").text
            dic["Intelligence"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(3) > a > div.characteristic-star-block").text
            dic["Potential For Mouthiness"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(4) > a > div.characteristic-star-block").text
            dic["Prey Drive"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(5) > a > div.characteristic-star-block").text
            dic["Tendency To Bark Or Howl"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(6) > a > div.characteristic-star-block").text
            dic["Wanderlust Potential"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(7) > a > div.characteristic-star-block").text

            dic["Energy Level"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(7) > div:nth-child(2) > a > div.characteristic-star-block").text
            dic["Intensity"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(7) > div:nth-child(3) > a > div.characteristic-star-block").text
            dic["Exercise Needs"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(7) > div:nth-child(4) > a > div.characteristic-star-block").text
            dic["Potential For Playfulness"] = driver.find_element_by_css_selector("body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(7) > div:nth-child(5) > a > div.characteristic-star-block").text

            lis_dic.append(dic)
            
        except:
            print("no funciona")
# Out:
# <ipython-input-67-ccb6aa27e150>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver)
# <ipython-input-67-ccb6aa27e150>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("body > div.ConsentManager__Overlay-np32r2-0.gDTHbw > div.Card-sc-1s2p2gv-0.Layer-sc-3vtlsk-0.ftFbdb.krUWJz > div.Frame-sc-1d4hofp-0.hmNhIY > button").click()
# <ipython-input-67-ccb6aa27e150>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("body > div.ConsentManager__Overlay-np32r2-0.gDTHbw > div.Card-sc-1s2p2gv-0.Layer-sc-3vtlsk-0.ftFbdb.krUWJz > div.Card__CardHeader-sc-1s2p2gv-1.Layer__StyledLayerHeader-sc-3vtlsk-1.cemlHZ.ggWNdk > div > button").click()
# ...

# %%
body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(6) > div:nth-child(2) > a > div.characteristic-star-block > div
        body > div.wrapper > div.inner-wrapper > div > article > div > div.breeds-single-details > div.js-listing-box.breed-characteristics-ratings > div:nth-child(7) > div:nth-child(2) > a > div.characteristic-star-block > div

# %%
lis_dic
# Out:
# [{'Name': 'Afador',
#   'Adapts Well To Apartment Living': '1',
#   'Good For Novice Owners': '1',
#   'Sensitivity Level': '3',
#   'Tolerates Being Alone': '3',
#   'Tolerates Cold Weather': '4',
#   'Tolerates Hot Weather': '2',
#   'Affectionate With Family': '4',
#   'Kid-Friendly': '2',
#   'Dog Friendly': '3',
#   'Friendly Toward Strangers': '1',
#   'Amount Of Shedding': '4',
#   'Drooling Potential': '3',
#   'Easy To Groom': '2',
#   'General Health': '3',
#   'Potential For Weight Gain': '4',
#   'Size': '4',
#   'Easy To Train': '1',
#   'Intelligence': '5',
#   'Potential For Mouthiness': '4',
#   'Prey Drive': '4',
#   'Tendency To Bark Or Howl': '4',
#   'Wanderlust Potential': '4',
#   'Energy Level': '4',
#   'Intensity': '4',
#   'Exercise Needs': '4',
#   'Potential For Playfulness': '3'},
#  {'Name': 'Affenhuahua',
#   'Adapts Well To Apartment Living': '4',
#   'Good For Novice Owners': '4',
#   'Sensitivity Level': '4',
#   'Tolerates Being Alone': '1',
# ...

# %%
per = pd.DataFrame(lis_dic)

# %%
per
# Out:
#                             Name Adapts Well To Apartment Living  \
# 0                         Afador                               1
# 1                    Affenhuahua                               4
# 2                  Affenpinscher                               5
# 3                   Afghan Hound                               5
# 4                         Akbash                               1
# ..                           ...                             ...
# 376  Wirehaired Pointing Griffon                               1
# 377               Xoloitzcuintli                               5
# 378               Yakutian Laika                               1
# 379                     Yorkipoo                               5
# 380            Yorkshire Terrier                               5
#
#     Good For Novice Owners Sensitivity Level Tolerates Being Alone  \
# 0                        1                 3                     3
# ...

# %%
per.to_csv("perretesbuenos.csv", index= False)

# %%
perretillos = pd.read_csv("perretesbuenos.csv")

# %%
perretillos
# Out:
#                             Name  Adapts Well To Apartment Living  \
# 0                         Afador                                1
# 1                    Affenhuahua                                4
# 2                  Affenpinscher                                5
# 3                   Afghan Hound                                5
# 4                         Akbash                                1
# ..                           ...                              ...
# 376  Wirehaired Pointing Griffon                                1
# 377               Xoloitzcuintli                                5
# 378               Yakutian Laika                                1
# 379                     Yorkipoo                                5
# 380            Yorkshire Terrier                                5
#
#      Good For Novice Owners  Sensitivity Level  Tolerates Being Alone  \
# 0                         1                  3                      3
# ...

# %%
apply y lambda
cada row astype int
# Out:
#   File "<ipython-input-87-3ca4a099635d>", line 1
#     cada row astype int
#          ^
# SyntaxError: invalid syntax
